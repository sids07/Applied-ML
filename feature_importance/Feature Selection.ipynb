# %% [markdown]
# ### Feature Selection

# %%
import pandas as pd

df = pd.read_csv('mobile-train.csv')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# #### Univariate Selection

# %%
X = df.iloc[:,:-1]
y = df['price_range']

# %%
X.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi
# ...

# %%
y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %%
from sklearn.feature_selection import SelectKBest #also called information gain
from sklearn.feature_selection import chi2

# %%
df.shape #20 features
# Out:
# (2000, 21)

# %%
order_rank_feature = SelectKBest(score_func=chi2,k=10)
ordered_feature=order_rank_feature.fit(X,y)
df_scores=pd.DataFrame(ordered_feature.scores_,columns=['Score'])
df_columns = pd.DataFrame(df.columns)

# %%
scores = pd.concat([df_columns,df_scores],axis=1)
scores.columns = ['Features','Scores']
scores
# Out:
#          Features         Scores
# 0   battery_power   14129.866576
# 1            blue       0.723232
# 2     clock_speed       0.648366
# 3        dual_sim       0.631011
# 4              fc      10.135166
# 5          four_g       1.521572
# 6      int_memory      89.839124
# 7           m_dep       0.745820
# 8       mobile_wt      95.972863
# 9         n_cores       9.097556
# 10             pc       9.186054
# 11      px_height   17363.569536
# 12       px_width    9810.586750
# 13            ram  931267.519053
# 14           sc_h       9.614878
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 17        three_g       0.327643
# 18   touch_screen       1.928429
# 19           wifi       0.422091
# 20    price_range            NaN

# %%
scores.nlargest(10,'Scores')
# Out:
#          Features         Scores
# 13            ram  931267.519053
# 11      px_height   17363.569536
# 0   battery_power   14129.866576
# 12       px_width    9810.586750
# 8       mobile_wt      95.972863
# 6      int_memory      89.839124
# 15           sc_w      16.480319
# 16      talk_time      13.236400
# 4              fc      10.135166
# 14           sc_h       9.614878

# %% [markdown]
# #### Feature Importance
#
# Gices us a score for each features higher the score of feature more relevant

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier()

# %%
print(model.feature_importances_)
# Out:
# [0.06093842 0.01848805 0.03250516 0.01934164 0.03186592 0.01748254
#  0.03431641 0.03314291 0.03539409 0.0330996  0.03295104 0.04669518
#  0.04865218 0.4012315  0.03395065 0.03250273 0.0346148  0.01372889
#  0.01881819 0.02028009]

# %%
ranked_features=pd.Series(model.feature_importances_,index= X.columns)
ranked_features.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# #### Correlation

# %%
import seaborn as sns
corr= df.iloc[:,:-1].corr()
corr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
top_feature = corr.index
plt.figure(figsize=(20,20))
sns.heatmap(df[top_feature].corr(),annot=True)

# %%
threshold = 0.5

def correlation(dataset,threshold):
    col_corr = set()
    corr_mat = dataset.corr()
    
    for i in range(len(corr_mat.columns)):
        for j in range(i):
            if abs(corr_mat.iloc[i,j])>threshold:
                colname = corr_mat.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
correlation(df.iloc[:,:-1],threshold)
# Out:
# {'pc', 'px_width', 'sc_w', 'three_g'}

# %% [markdown]
# Here we can use any of the correlated feature.
#
# Why?
#
# Because they are independent feature which will effect dependent features. They cant be correlated otherwise they will be almost same feature i.e. duplicate features

# %% [markdown]
# ### Information Gain

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
mutual_info = mutual_info_classif(X,y)

# %%
mutual_data=pd.Series(mutual_info,index=X.columns)
mutual_data.sort_values(ascending=False)
# Out:
# ram              0.848308
# battery_power    0.031451
# px_width         0.030487
# three_g          0.027146
# px_height        0.022819
# mobile_wt        0.016117
# talk_time        0.013745
# four_g           0.009712
# n_cores          0.004872
# fc               0.004451
# wifi             0.003360
# dual_sim         0.002809
# clock_speed      0.001688
# pc               0.000000
# touch_screen     0.000000
# sc_h             0.000000
# m_dep            0.000000
# int_memory       0.000000
# sc_w             0.000000
# blue             0.000000
# dtype: float64

# %% [markdown]
# ##### postive number which measures are dependices. It is equalto zero if and only if two random variables are independent, and higher values mean higher dependency.
