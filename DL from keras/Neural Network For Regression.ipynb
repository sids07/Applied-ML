# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading Datas

# %%
boston_house = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/Boston_Housing/Training_set_boston.csv")

# %%
boston_house.head()
# Out:
#        CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 0  15.02340   0.0  18.10   0.0  0.6140  5.304  97.3  2.1007  24.0  666.0
# 1   0.62739   0.0   8.14   0.0  0.5380  5.834  56.5  4.4986   4.0  307.0
# 2   0.03466  35.0   6.06   0.0  0.4379  6.031  23.3  6.6407   1.0  304.0
# 3   7.05042   0.0  18.10   0.0  0.6140  6.103  85.1  2.0218  24.0  666.0
# 4   0.72580   0.0   8.14   0.0  0.5380  5.727  69.5  3.7965   4.0  307.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     20.2  349.48  24.91  12.0
# 1     21.0  395.62   8.47  19.9
# 2     16.9  362.25   7.83  19.4
# 3     20.2    2.52  23.29  13.4
# 4     21.0  390.95  11.28  18.2

# %%
boston_house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 14 columns):
# CRIM       404 non-null float64
# ZN         404 non-null float64
# INDUS      404 non-null float64
# CHAS       404 non-null float64
# NOX        404 non-null float64
# RM         404 non-null float64
# AGE        404 non-null float64
# DIS        404 non-null float64
# RAD        404 non-null float64
# TAX        404 non-null float64
# PTRATIO    404 non-null float64
# B          404 non-null float64
# LSTAT      404 non-null float64
# MEDV       404 non-null float64
# dtypes: float64(14)
# memory usage: 44.3 KB

# %%
boston_house.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.609125   11.569307   10.985050    0.071782    0.556484    6.315891
# std      8.875058   23.152481    6.894618    0.258447    0.117704    0.709452
# min      0.009060    0.000000    0.740000    0.000000    0.385000    3.863000
# 25%      0.081437    0.000000    5.130000    0.000000    0.452000    5.890500
# 50%      0.261390    0.000000    8.560000    0.000000    0.538000    6.210000
# 75%      3.202962   20.000000   18.100000    0.000000    0.631000    6.636750
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    68.556436    3.808195    9.356436  404.032178   18.318317  356.278342
# ...

# %% [markdown]
# ##### MEDV is the target or dependent variable. And rest are the features or independent variable.

# %%
X = boston_house.iloc[:,:-1]
y = boston_house.MEDV

# %%
X.head()
# Out:
#        CRIM    ZN  INDUS  CHAS     NOX     RM   AGE     DIS   RAD    TAX  \
# 0  15.02340   0.0  18.10   0.0  0.6140  5.304  97.3  2.1007  24.0  666.0
# 1   0.62739   0.0   8.14   0.0  0.5380  5.834  56.5  4.4986   4.0  307.0
# 2   0.03466  35.0   6.06   0.0  0.4379  6.031  23.3  6.6407   1.0  304.0
# 3   7.05042   0.0  18.10   0.0  0.6140  6.103  85.1  2.0218  24.0  666.0
# 4   0.72580   0.0   8.14   0.0  0.5380  5.727  69.5  3.7965   4.0  307.0
#
#    PTRATIO       B  LSTAT
# 0     20.2  349.48  24.91
# 1     21.0  395.62   8.47
# 2     16.9  362.25   7.83
# 3     20.2    2.52  23.29
# 4     21.0  390.95  11.28

# %%
y
# Out:
# 0      12.0
# 1      19.9
# 2      19.4
# 3      13.4
# 4      18.2
#        ...
# 399    19.5
# 400    21.1
# 401    24.5
# 402    13.4
# 403    18.6
# Name: MEDV, Length: 404, dtype: float64

# %%
from sklearn.model_selection import KFold

# %%
k = KFold(n_splits=5,random_state=42)
# Out:
# /home/sid/.local/lib/python3.6/site-packages/sklearn/model_selection/_split.py:297: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   FutureWarning

# %%
for i, (train_idx,test_idx) in enumerate(k.split(X)):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    print("For fold {}, we have training_data :{} and testing_data:{}".format(i,train_idx,test_idx))
# Out:
# For fold 0, we have training_data :[ 81  82  83  84  85  86  87  88  89  90  91  92  93  94  95  96  97  98
#   99 100 101 102 103 104 105 106 107 108 109 110 111 112 113 114 115 116
#  117 118 119 120 121 122 123 124 125 126 127 128 129 130 131 132 133 134
#  135 136 137 138 139 140 141 142 143 144 145 146 147 148 149 150 151 152
#  153 154 155 156 157 158 159 160 161 162 163 164 165 166 167 168 169 170
#  171 172 173 174 175 176 177 178 179 180 181 182 183 184 185 186 187 188
#  189 190 191 192 193 194 195 196 197 198 199 200 201 202 203 204 205 206
#  207 208 209 210 211 212 213 214 215 216 217 218 219 220 221 222 223 224
#  225 226 227 228 229 230 231 232 233 234 235 236 237 238 239 240 241 242
#  243 244 245 246 247 248 249 250 251 252 253 254 255 256 257 258 259 260
#  261 262 263 264 265 266 267 268 269 270 271 272 273 274 275 276 277 278
#  279 280 281 282 283 284 285 286 287 288 289 290 291 292 293 294 295 296
# ...

# %%
n_features = X.shape[1]

# %%
n_features
# Out:
# 13

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras import Input
from tensorflow.keras import Model

# %%
import tensorflow
from numpy.random import seed

# %%
data = Input(shape=(n_features,))

hidden = Dense(10,activation="relu")(data)

output = Dense(1)(hidden)

model = Model(inputs = data, outputs=output)

# %%
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 13)]              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                140
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 11
# ...
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

optimizers = RMSprop(0.01)

model.compile(loss="mean_squared_error",optimizer=optimizers)

# %%
seed_value = 42
seed(seed_value)        # If you build the model with given parameters, set_random_seed will help you produce the same result on multiple execution


# Recommended by Keras -------------------------------------------------------------------------------------
# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)
# Recommended by Keras -------------------------------------------------------------------------------------

tensorflow.random.set_seed(seed_value)

# %%
val_loss = []
for i, (train_idx,test_idx) in enumerate(k.split(X)):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    model.fit(X_train,y_train,epochs=10,batch_size=30,verbose=1)
    
    valloss= model.evaluate(X_test,y_test)
    
    val_loss.append(valloss)
    
print("Final Validation Loss :{}".format(sum(val_loss)/len(val_loss)))
# Out:
# Epoch 1/10
# 11/11 [==============================] - 0s 3ms/step - loss: 7307.9448
# Epoch 2/10
# 11/11 [==============================] - 0s 2ms/step - loss: 266.0879
# Epoch 3/10
# 11/11 [==============================] - 0s 2ms/step - loss: 136.8942
# Epoch 4/10
# 11/11 [==============================] - 0s 2ms/step - loss: 94.0223
# Epoch 5/10
# 11/11 [==============================] - 0s 1ms/step - loss: 80.6827
# Epoch 6/10
# 11/11 [==============================] - 0s 1ms/step - loss: 114.8695
# Epoch 7/10
# 11/11 [==============================] - 0s 1ms/step - loss: 106.0645
# Epoch 8/10
# 11/11 [==============================] - 0s 1ms/step - loss: 107.5153
# Epoch 9/10
# 11/11 [==============================] - 0s 1ms/step - loss: 117.4737
# Epoch 10/10
# ...
# 3/3 [==============================] - 0s 1ms/step - loss: 47.1063
# Epoch 1/10
# 11/11 [==============================] - 0s 1ms/step - loss: 84.9782
# Epoch 2/10
# ...

# %% [markdown]
# ### Hyperparameters tuning

# %% [markdown]
# Most machine learning problems require a lot of hyperparameter tuning. Unfortunately, we can't provide concrete tuning rules for every model. Lowering the learning rate can help one model converge efficiently but make another model converge much too slowly. You must experiment to find the best set of hyperparameters for your dataset. That said, here are a few rules of thumb:
#
# Training loss should steadily decrease, steeply at first, and then more slowly until the slope of the curve reaches or approaches zero.
#
# If the training loss does not converge, train for more epochs.
#
# If the training loss decreases too slowly, increase the learning rate. Note that setting the learning rate too high may also prevent training loss from converging.
#
# If the training loss varies wildly (that is, the training loss jumps around), decrease the learning rate.
#
# Lowering the learning rate while increasing the number of epochs or the batch size is often a good combination.
#
# Setting the batch size to a very small batch number can also cause instability. First, try large batch size values. Then, decrease the batch size until you see degradation.
#
# For real-world datasets consisting of a very large number of examples, the entire dataset might not fit into memory. In such cases, you'll need to reduce the batch size to enable a batch to fit into memory.
# Remember: the ideal combination of hyperparameters is data dependent, so you must always experiment and verify.

# %% [markdown]
# ### It can be done with 1. Sklearn and 2. Keras

# %% [markdown]
# #### Sklearn

# %% [markdown]
# We cann't use native sklearn as model is defined by keras. So, we must integrate keras and sklearn properly.
#
# So, we first create function which allows us to create model in our old keras way.
#
# Then, we define KerasRegressor model which is an sklearn api for keras.

# %%
from keras.wrappers.scikit_learn import KerasRegressor

# %%
def create_model(optimizers=RMSprop(0.01)):
    inp = Input(shape=(n_features,))
    
    hid = Dense(10,activation="relu")(inp)
    
    hid = Dense(8,activation="relu")(hid)
    
    out = Dense(1)(hid)
    
    model = Model(inputs=inp, outputs= out)
    
    model.compile(loss="mean_squared_error",metrics=['mse'],optimizer=optimizers)
    
    return model

# %%
model = KerasRegressor(build_fn=create_model,verbose=1)

# %%
batch_size = [10,20,30,40,50]

epochs=[10,20,50]

params_grid = {'batch_size':batch_size,'epochs':epochs}

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

# %%
X_tra,X_tes,y_tra,y_tes = train_test_split(X,y,test_size=0.2,random_state=43)
