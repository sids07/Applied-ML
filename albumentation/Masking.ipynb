# %%
import albumentations as A
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('sid.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(img)

# %%
import random
transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.ShiftScaleRotate(shift_limit=0.05,scale_limit=0.3,rotate_limit=(-35,45),border_mode=cv2.BORDER_CONSTANT,p=0.5)

],p=1)

random.seed(42)

agumented_image = transform(image=img,mask=mask)['mask']
plt.axis('off')
plt.imshow(agumented_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-514324ac7d1b> in <module>
#       8 random.seed(42)
#       9
# ---> 10 agumented_image = transform(image=img,mask=mask)['mask']
#      11 plt.axis('off')
#      12 plt.imshow(agumented_image)
#
# NameError: name 'mask' is not defined

# %%
transform = A.ShiftScaleRotate(shift_limit=0.05,scale_limit=0.3,rotate_limit=(-35,45),border_mode=cv2.BORDER_CONSTANT,p=0.5)

b_transform = transform(image = img,mask=mask)
plt.imshow(b_transform['mask'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-8622237644cb> in <module>
#       1 transform = A.ShiftScaleRotate(shift_limit=0.05,scale_limit=0.3,rotate_limit=(-35,45),border_mode=cv2.BORDER_CONSTANT,p=0.5)
#       2
# ----> 3 b_transform = transform(image = img,mask=mask)
#       4 plt.imshow(b_transform['mask'])
#
# NameError: name 'mask' is not defined
